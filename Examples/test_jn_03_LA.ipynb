# %%
# %config Completer.use_jedi = False

# %%
from tessellation import Tessellation

# %% [markdown]
# # Create Tessllation Object

# %%
los_angeles= Tessellation('Los Angeles')

# %%
los_angeles_poly=los_angeles.get_polygon()

# %%
los_angeles_poly
# Out:
#    osm_id                                           geometry
# 0  207359  POLYGON ((-118.66818 34.18771, -118.66817 34.1...

# %%
los_angeles_poly.plot().set_axis_off();

# %% [markdown]
# # Squares and Hexagons

# %%
los_angeles_hex=los_angeles.hexagons(7)
los_angeles_hex.plot(lw=1, edgecolor='w').set_axis_off();

# %%
los_angeles_sqr=los_angeles.squares(13)
los_angeles_sqr.plot(lw=0.5, edgecolor='w').set_axis_off();

# %% [markdown]
# # Voronoi

# %%
los_angeles_voronoi= los_angeles.voronoi(cluster_algo='k-means',
                        poi_categories=['public_transport'],
                        timeout=60,
                        n_polygons=50,
                        verbose=True)
# Out:
# Getting data from OSM...
# 100% (4674 of 4674) |####################| Elapsed Time: 0:00:00 Time:  0:00:00
# Creating POI DataFrame...
# Cleaning POI DataFrame...
# K-Means Clustering...
# Creating Voronoi polygons...

# %%
los_angeles_voronoi
# Out:
#                                              geometry
# 0   MULTIPOLYGON (((-118.56842 34.12417, -118.5700...
# 1   POLYGON ((-118.43901 34.01779, -118.44784 34.0...
# 2   POLYGON ((-118.28108 34.03787, -118.27833 34.0...
# 3   POLYGON ((-118.25036 33.79985, -118.23932 33.7...
# 4   MULTIPOLYGON (((-118.38968 34.05295, -118.3910...
# 5   POLYGON ((-118.35290 34.12034, -118.38489 34.1...
# 6   POLYGON ((-118.33519 33.98029, -118.32224 33.9...
# 7   POLYGON ((-118.40486 34.00066, -118.40024 34.0...
# 8   POLYGON ((-118.31373 34.03529, -118.31375 34.0...
# 9   POLYGON ((-118.16040 34.08171, -118.18933 34.0...
# 10  POLYGON ((-118.42718 34.12647, -118.48194 34.1...
# 11  POLYGON ((-118.25331 34.11942, -118.25077 34.1...
# 12  POLYGON ((-118.57007 34.10922, -118.51931 34.1...
# 13  POLYGON ((-118.23721 34.09729, -118.23689 34.1...
# 14  POLYGON ((-118.39172 34.02680, -118.40061 34.0...
# 15  POLYGON ((-118.51171 33.93650, -118.44814 34.0...
# 16  POLYGON ((-118.18272 34.12949, -118.20364 34.1...
# 17  POLYGON ((-118.23932 33.76850, -118.25036 33.7...
# 18  POLYGON ((-118.29050 33.85630, -118.30915 33.8...
# 19  POLYGON ((-118.36703 34.00972, -118.35687 34.0...
# 20  MULTIPOLYGON (((-118.39108 34.05711, -118.3896...
# 21  POLYGON ((-118.31121 33.76440, -118.24856 33.7...
# 22  POLYGON ((-118.34346 34.09433, -118.35290 34.1...
# 23  POLYGON ((-118.44080 34.04700, -118.44820 34.0...
# 24  MULTIPOLYGON (((-118.34338 34.09412, -118.3359...
# 25  POLYGON ((-118.51638 34.32783, -118.48787 34.2...
# 26  MULTIPOLYGON (((-118.42962 33.91657, -118.4265...
# 27  POLYGON ((-118.34361 34.03970, -118.35687 34.0...
# 28  POLYGON ((-118.26078 33.92310, -118.27002 33.9...
# 29  POLYGON ((-118.25641 33.97005, -118.26249 33.9...
# 30  POLYGON ((-118.43617 33.97828, -118.43395 33.9...
# 31  POLYGON ((-118.40852 34.22578, -118.37324 34.2...
# 32  POLYGON ((-118.28320 33.89686, -118.29176 33.8...
# 33  MULTIPOLYGON (((-118.40024 34.00210, -118.4048...
# 34  POLYGON ((-118.28502 34.06033, -118.28577 34.0...
# 35  POLYGON ((-118.25692 34.05781, -118.23721 34.0...
# 36  POLYGON ((-118.28502 34.06033, -118.31375 34.0...
# 37  POLYGON ((-118.56869 34.29474, -118.56813 34.2...
# 38  POLYGON ((-118.29881 33.80767, -118.30881 33.8...
# 39  POLYGON ((-118.43901 34.01779, -118.44080 34.0...
# 40  POLYGON ((-118.31428 34.22149, -118.34214 34.2...
# 41  POLYGON ((-118.19339 34.05628, -118.18933 34.0...
# 42  POLYGON ((-118.45092 34.01268, -118.44784 34.0...
# 43  POLYGON ((-118.48198 34.12401, -118.51931 34.1...
# 44  MULTIPOLYGON (((-118.44095 33.99437, -118.4481...
# 45  POLYGON ((-118.31373 34.03529, -118.32098 34.0...
# 46  MULTIPOLYGON (((-118.37121 34.28611, -118.3731...
# 47  POLYGON ((-118.23198 34.02659, -118.22135 34.0...
# 48  POLYGON ((-118.50174 34.04280, -118.51931 34.1...
# 49  POLYGON ((-118.31373 34.03529, -118.28108 34.0...

# %%
los_angeles_voronoi.plot(lw=1, edgecolor='w').set_axis_off();
print(len(los_angeles_voronoi), 'polygons')
# Out:
# 50 polygons

# %%
los_angeles_voronoi= los_angeles.voronoi(cluster_algo='k-means',
                        poi_categories=['shop'],
                        timeout=60,
                        n_polygons=100,
                        verbose=True)
# Out:
# Getting data from OSM...
# 100% (4394 of 4394) |####################| Elapsed Time: 0:00:00 Time:  0:00:00
# Creating POI DataFrame...
# Cleaning POI DataFrame...
# K-Means Clustering...
# Creating Voronoi polygons...

# %%
los_angeles_voronoi.plot(lw=1, edgecolor='w').set_axis_off();
print(len(los_angeles_voronoi), 'polygons')
# Out:
# 100 polygons

# %%
los_angeles.get_poi_data()
# Out:
#       type                                           geometry  \
# 0      way  [{'lat': 34.0632896, 'lon': -118.1690445}, {'l...
# 1      way  [{'lat': 34.2523449, 'lon': -118.5994834}, {'l...
# 2      way  [{'lat': 34.2537951, 'lon': -118.5996288}, {'l...
# 3      way  [{'lat': 34.2307753, 'lon': -118.5458971}, {'l...
# 4      way  [{'lat': 34.2114541, 'lon': -118.4474721}, {'l...
# ...    ...                                                ...
# 4669  node         [{'lat': 34.2314794, 'lon': -118.2657852}]
# 4670  node         [{'lat': 34.2319431, 'lon': -118.2665563}]
# 4671  node         [{'lat': 34.1237751, 'lon': -118.3753688}]
# 4672  node         [{'lat': 34.1237137, 'lon': -118.3756135}]
# 4673  node          [{'lat': 34.1828994, 'lon': -118.590408}]
#
#                                                    tags  center_latitude  \
# 0     {'bicycle': 'yes', 'bus': 'yes', 'highway': 'f...        34.063239
# 1     {'area': 'yes', 'bicycle': 'dismount', 'foot':...        34.252854
# 2     {'area': 'yes', 'bicycle': 'dismount', 'foot':...        34.252797
# 3     {'highway': 'path', 'public_transport': 'platf...        34.230642
# 4     {'area': 'yes', 'network': 'Amtrak;Metrolink',...        34.211207
# ...                                                 ...              ...
# 4669  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...        34.231479
# 4670  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...        34.231943
# 4671  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...        34.123775
# 4672  {'bus': 'yes', 'highway': 'bus_stop', 'name': ...        34.123714
# 4673  {'bus': 'yes', 'highway': 'bus_stop', 'public_...        34.182899
#
#       center_longitude  public_transport
# 0          -118.168858              True
# 1          -118.599461              True
# 2          -118.599599              True
# 3          -118.545226              True
# 4          -118.446462              True
# ...                ...               ...
# 4669       -118.265785              True
# 4670       -118.266556              True
# 4671       -118.375369              True
# 4672       -118.375614              True
# 4673       -118.590408              True
#
# [4674 rows x 6 columns]

# %%
los_angeles_voronoi_hdbscan= los_angeles.voronoi(cluster_algo='hdbscan',
                                poi_categories=['public_transport'],
                                timeout=30,
                                min_cluster_size=15,
                                verbose=True)
# Out:
# HDBSCAN Clustering... This can take a while...
# Creating Voronoi polygons...

# %%
los_angeles_voronoi_hdbscan.plot(lw=1, edgecolor='w').set_axis_off();
